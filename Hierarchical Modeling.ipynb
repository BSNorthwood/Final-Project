# %% [markdown]
# Here we will run the hierarchical modeling.
# We load all needed Libraries

# %%
import pandas as pd
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We load the dataset

# %%
df = pd.read_csv("Final_encoded.csv")

# %% [markdown]
# We select the features we wish to use.

# %%
df_selected = df[['Profession', 'Work_Experience', 'Family_Size']]

# %% [markdown]
# We standardize the data for this model

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_selected)

# %% [markdown]
# We perform the hierarchical clustering

# %%
linkage_matrix = sch.linkage(df_scaled, method='ward')  # 'ward' minimizes variance within clusters

# %% [markdown]
# We now plot and display the dendogram

# %%
plt.figure(figsize=(10, 6))
sch.dendrogram(linkage_matrix, labels=df.index, leaf_rotation=90, leaf_font_size=10)
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.title("Hierarchical Clustering Dendrogram")
plt.grid()
plt.show()
